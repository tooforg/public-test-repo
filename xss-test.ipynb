# %%
print('Hello World')
# Out:
# test

# %%
display(HTML('<b>test</b>'))
# Out:
# test

# %%
from IPython.display import Javascript
# Out:
# test

# %%
display(HTML('''<a href="javascript:alert(document.domain)">click</a>'''))
# Out:
# test

# %%
display(HTML('''<details><summary>Click</summary><img src=x onerror=alert(document.domain)></details>'''))
# Out:
# test

# %%
# mXSS payload
# Out:
# test

# %%
# iframe payload
# Out:
# test

# %% [markdown]
# # Markdown cell
#
# <img src=x onerror=alert('md-xss')>
#
# [link](javascript:alert(document.domain))
