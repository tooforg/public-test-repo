# %%
# SVG MIME type
# Out:
# test

# %%
# base tag
# Out:
# test

# %%
# form
# Out:
# test

# %%
# meta refresh
# Out:
# test

# %%
# CSS
# Out:
# test

# %%
# MathJax
# Out:
# test

# %%
# object embed
# Out:
# test

# %%
# noscript
# Out:
# test

# %%
# template
# Out:
# test

# %%
# textarea mutation
# Out:
# test
