# %%
NB_TEST_SOURCE_CELL
# Out:
# plain text fallback
# plain text fallback 2
# plain text fallback 3
# plain text fallback 4
# plain text fallback 5
# svg mime fallback

# %% [markdown]
# ## NB_TEST_MARKDOWN_HEADER
# <i>NB_TEST_MARKDOWN_INLINE_HTML</i>
# $\href{javascript:window.NB_XSS_MATH=1}{\text{NB_TEST_MATH_HREF}}$
